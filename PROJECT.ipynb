# %%
from tkinter import *
import tkinter as tk
from tkinter import ttk
from tkinter import messagebox
from PIL import Image ,ImageTk

bmi = 0 


class FirstPage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        border = tk.LabelFrame(self, text='Login', bg='green',bd=10,font=("Arial",20))
        
        
        
    
        
        border = tk.LabelFrame(self, text='Login', bg='green',bd=10,font=("Arial",20))
        border.pack(fill="both",expand="yes", padx = 150, pady= 150)
        
        L1 = tk.Label(border,text="username",font=("Black Chancery",15))
        L1.place(x=50,y=20)
        T1 = tk.Entry(border, width = 30, bd = 5)
        T1.place(x=180,y=20)
        
        L2 = tk.Label(border,text="password",font=("Black Chancery",15))
        L2.place(x=50,y=80)
        T2 = tk.Entry(border, width = 30,show="*", bd = 5)
        T2.place(x=180,y=80)
        
        def verify():
            with open("INFO.txt","r") as f:
                info = f.readlines()
                i = 0
                for e in info:
                    u,p =e.split(",")
                    if u.strip() == T1.get() and p.strip() == T2.get():
                        controller.show_frame(SecondPage)
                        i = 1
                        break
                if i==0:
                    messagebox.showinfo("Error","Please provide correct username and password!!")
           
    
        B1 = tk.Button(border, text = "Submit",bg="yellow", font=("Black Chancery",15), command=verify)
        B1.place(x=320, y=115)
        
        def register():
            window = tk.Tk()
            window.resizable(0,0)
            window.configure(bg="orange")
            window.title("Register")
            l1 = tk.Label(window, text="username:",font=("Arial",15),bg="brown")
            l1.place(x=10, y=10)
            t1= tk.Entry(window, width=30, bd=5)
            t1.place(x=200, y=10)
            
            l2 = tk.Label(window, text="password:",font=("Arial",15),bg="brown")
            l2.place(x=10, y=60)
            t2= tk.Entry(window, width=30,show="*", bd=5)
            t2.place(x=200, y=60)
            
            l3 = tk.Label(window, text="confirm password:", font=("Arial",15),bg="brown")
            l3.place(x=10, y=110)
            t3= tk.Entry(window, width=30,show="*", bd=5)
            t3.place(x=200, y=110)
            
            def check():
                if t1.get()!="" or t2.get()!="" or t3.get()!="":
                    if t2.get()==t3.get():
                        with open("INFO.txt","a") as f:
                            f.write(t1.get()+","+t2.get()+"\n")
                            messagebox.showinfo("welcome","You are registered sucessfully")
                    else:
                        messagebox.showinfo("Error","Your password didn't get match!!")
                else:
                    messagebox.showinfo("Error","Please fill the complete field!!")
            
            b1 = tk.Button(window, text="sign in", font=("Arial",15),bg="purple",command=check)
            b1.place(x= 170, y=150)
            
            window.geometry("470x220")
            window.mainloop()
        
        B2 = tk.Button(self, text="Register", bg= "sky blue", font=("Arial",15),command=register)
        B2.place(x=650, y=20)
    
    
class SecondPage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent)
        
        def calculate_bmi(weight,height):
            global bmi
            height = height/100
            bmi = (weight/(height**2))
            return bmi
            #mi_index(bmi)
        
        
        
        
        def alter_display():
            global bmi
            height = float(height_entry.get())
            weight = float(weight_entry.get())
            bmi = calculate_bmi(weight,height)
            print("alter_display :",bmi)
            answer_label.place(x=50,y=140)
            answer_entry.place(x=280,y=140)
            answer_entry.insert(0,round(bmi,2))
            #print(bmi)
        
        def reset_entry():
            #age_tf.delete(0,'end')
            height_entry.delete(0,'end')
            weight_entry.delete(0,'end')
            answer_entry.delete(0,'end')
            fitness_entry.delete(0,'end')
            
           
            
        
                
        border1 = tk.LabelFrame(self,text=" BODY MASS INDEX" , bg='pink',bd=10,font=("Arial",20))
        border1.pack(fill="both",expand="yes", padx = 150, pady= 60)
        
        weight_label = tk.Label(border1,text="Enter Your weigth(kg)",font=("Black Chancery",15),bg= "silver")
        weight_label.place(x=50,y=20)
        weight_entry = tk.Entry(border1, width = 30, bd = 5)
        weight_entry.place(x=280,y=20)
        
        
        height_label= tk.Label(border1,text="Enter your heigth(cm)",font=("Black Chancery",15),bg= "silver")
        height_label.place(x=50,y=80)
        height_entry = tk.Entry(border1, width = 30, bd = 5)
        height_entry.place(x=280,y=80)
        
            
            
        
        
        
                
        
        
        
        answer_label = tk.Label(border1,text="Your BMI is ",font=("Black Chancery",15),bg= "silver")
        
        answer_entry= tk.Entry(border1, width = 30, bd = 5)
        
        
    
       
        
        
    
        
        
            
        
        
        
        B3 = tk.Button(self, text="Calculate", bg= "orange", font=("Arial",15),command=alter_display)
        B3.place(x=250, y=350)
        
        B4 =tk.Button(self, text="Reset", bg= "orange", font=("Arial",15),command=reset_entry)
        B4.place(x=350, y=350)
        
        L9 = tk.Label(border1,text="Your fitness",bg="silver",font=("Black Chancery",15))
        L9.place(x=50,y=200)
        fitness_entry= tk.Entry(border1, width = 30, bd = 5)
        fitness_entry.place(x=280,y=200)
        
        
        
        def bmi_index():
            global bmi
            show = ""
            #print("bmi :",bmi)
            if bmi <=16:
                #print(bmi)
                show="severly underweight"
            elif bmi > 16 and bmi < 18.5:
                #print(bmi)
                show="underweight"
            elif bmi > 18.5 and bmi < 24.9:
                #print(bmi)
                show="Normal/Healthy"
            elif bmi > 24.9 and bmi < 29.9:
                #print(bmi)
                show="overweight"
            elif bmi > 29.9:
                #print(bmi)
                show="severly overweight"
            else:
                show="error"
                #print(bmi)
            fitness_entry.insert(tk.END,show)
        
        B6 = tk.Button(self, text="Fitness", bg= "orange", font=("Arial",15),command=bmi_index)
        B6.place(x=450, y=350)
                
        
        
        
        
        
      
        
        
            
                
        
        
        
        
        
        #Label = tk.Label(self,text="Second page",font=("Black Chancery",30))
        #Label.place(x=230,y=230)
    
        Button = tk.Button(self, text = "Next", font=("Black Chancery",15),bg="sky blue", command=lambda:controller.show_frame(ThirdPage))
        Button.place(x=650, y=450)
    
        Button = tk.Button(self, text = "Back", font=("Black Chancery",15),bg="sky blue", command=lambda:controller.show_frame(FirstPage))
        Button.place(x=100, y=450)
    
    
class ThirdPage(tk.Frame):
    def __init__(self,parent,controller):
        tk.Frame.__init__(self,parent) 
    
        border2 = tk.LabelFrame(self, text='HEALTH RISKS AND SOLUTIONS', bg='Turquoise',bd=10,font=("Arial",15))
        border2.pack(fill="both",expand="yes", padx = 80, pady= 50)
        
        
        def severely_underweight():
            body="severely underweight"
            if body=="severely underweight":
                    messagebox.showinfo("HEALTH RISK", "Malnutrition,Hair loss, Skin and teeth problems,anemia, irregular periods and infertility('for women'),lack of growth, osteoporosis.")
                    messagebox.showinfo("SOLUTIONS TO MAINTAIN BMI", " 1. Eat more frequently to gain a lot of mass(consume right calories of food")
        B8 = tk.Button(border2, text="severely underweight", bg= "orange", font=("Arial",15),command=severely_underweight)
        B8.place(x=30, y=30)       
                    
        def underweight():
            body1="underweight"
            if body1=="underweight":
                messagebox.showinfo("HEALTH RISKS"," Malnutrition, Hair loss, anemia, irregular periods(for women), lack of growth, osteoporosis, surgical complications,low immunity, infertility(for womens).")
                messagebox.showinfo("SOLUTIONS TO MAINTAIN BMI","  1. Drink water frequently 3-4 litres per day.   2. Exercise.   3. Add healthy calories to your diet.   4. Eat Plenty of Protein.   5. Drink smoothies and shakes.")
        B9 = tk.Button(border2, text="underweight", bg= "orange", font=("Arial",15),command=underweight)
        B9.place(x=30, y=100)      
                
        def severely_overweight():
            body2="severely_overweight"
            if body2=="severely_overweight":
                messagebox.showinfo("HEALTH RISKS","High blood pressure, risks of heart attack, arthritis problem,metabolic faliures, hormonal impairments, diabeties, breathing problems, cholesterol issue, depression and anxiety.")
                messagebox.showinfo("SOLUTIONS TO MAINTAIN BMI", "1. Be as physically active as possible(exercises, cardio, walking and running on a regular basis).   2. Stay hydrated with water and avoid drinks with added sugar.   3. Keep track of what you eat in a food diary.   4. Limit portion size to control calorie intake.   5. Consult a therapist if needed.   6. Under the consultant of doctor weight-loss medicines.")
        
        B10 = tk.Button(border2, text="severely overweight", bg= "orange", font=("Arial",15),command=severely_overweight)
        B10.place(x=30, y=170)
        
        def overweight():
            body3="overweight"
            if body3=="overweight":
                messagebox.showinfo("HEALTH RISKS","High blood pressure, type-2 diabeties, breathing problems, cholesterol issue, depression and anxiety.")
                messagebox.showinfo("SOLUTIONS TO MAINTAIN BMI","1. Have a healthy eating plan.2. Drink more water.3. Exercise daily.4. Make a goal and stick to it(walking daily).5. Do not eat foods which have high quantity of oils,fats and proteins.")
        B11 = tk.Button(border2, text="overweight", bg= "orange", font=("Arial",15),command=overweight)
        B11.place(x=30, y=240)   
        #L8 = tk.Label(border2,text="Enter your BMI",bg="silver",font=("Black Chancery",15))
        #L8.place(x=50,y=140)
        #bmi_entry= tk.Entry(border2, width = 30, bd = 5)
        #bmi_entry.place(x=230,y=140)
        #
        #B8 = tk.Button(border2, text="severely underweight", bg= "orange", font=("Arial",15),command=severely_underweight)
        #B8.place(x=30, y=30)
        
        #B9 = tk.Button(border2, text="Insert BMI", bg= "orange", font=("Arial",15))
        #B9.place(x=150, y=30)
        #
        #B10 = tk.Button(border2, text="Insert BMI", bg= "orange", font=("Arial",15))
        #B10.place(x=300, y=30)
        #
        #B11 = tk.Button(border2, text="Insert BMI", bg= "orange", font=("Arial",15))
        #B11.place(x=450, y=30)
        
        
        
    
        
        
    
        Button = tk.Button(self, text = "Home", bg="sky blue",font=("Black Chancery",15), command=lambda:controller.show_frame(FirstPage))
        Button.place(x=650, y=450)
    
    
        Button = tk.Button(self, text = "Back",bg="sky blue", font=("Black Chancery",15), command=lambda:controller.show_frame(SecondPage))
        Button.place(x=100, y=450)
    
    
    
class Application(tk.Tk):
    def __init__(self,*args,**kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
            
         #creating a window
            
        window = tk.Frame(self)
        window.pack()
            
        window.grid_rowconfigure(0,minsize = 500)
        window.grid_columnconfigure(0,minsize = 800)
            
        self.frames = {}
        for F in (FirstPage, SecondPage, ThirdPage):
            frame = F(window, self)
            self.frames[F] = frame
            frame.grid(row = 0,column=0, sticky="nsew")
                
        self.show_frame(FirstPage)
        #self.show_frame(SecondPage)
            
    def show_frame(self, page):
        frame = self.frames[page]
        frame.tkraise()
                
app=Application()
app.maxsize(800,500)
app.mainloop()
# Out:
#   File "C:\Users\prem1\AppData\Local\Temp/ipykernel_7912/3779691176.py", line 309
#     image2 =Image.open('C:\Users\prem1\Documents\Rittik')
#                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
